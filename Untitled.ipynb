# %%
import pandas as pd

# %%
dataset = pd.read_csv("demo.csv")

# %%
dataset
# Out:
#              X             Y
# 0    -0.500000  3.551448e-23
# 1    -0.499756  7.328364e-23
# 2    -0.499512  1.108591e-22
# 3    -0.499268  1.481237e-22
# 4    -0.499023  1.849264e-22
# ...        ...           ...
# 2044 -0.000977  6.369325e-19
# 2045 -0.000732  6.162599e-19
# 2046 -0.000488  5.180799e-19
# 2047 -0.000244  3.587565e-19
# 2048  0.000000  1.635256e-19
#
# [2049 rows x 2 columns]

# %%
dataset.dtypes
# Out:
# X    float64
# Y    float64
# dtype: object

# %%
X = dataset.iloc[:, 0]
Y = dataset.iloc[:, 1]

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y,0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(X,Y)
plt.show()
